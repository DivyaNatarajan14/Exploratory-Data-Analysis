# %% [markdown]
# #IMPORTING LIBRARIES

# %% [markdown]
# pandas (import pandas as pd): For handling structured data with DataFrames.
#
# numpy (import numpy as np): For numerical operations on arrays and matrices.
#
# matplotlib (import matplotlib.pyplot as plt): For creating static visualizations.
#
# seaborn (import seaborn as sb): For creating attractive statistical visualizations.
#
# Setting display options (pd.set_option): Adjusts options to display all columns and limit rows to 150 for better data exploration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

#display all columns and rows of the dataframe
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', 150)

# %% [markdown]
# IMPORTING DATA SET
#
# Upload a file from your local machine to your Colab environment
#
# uploaded = files.upload()
#
# Download a file from your Colab environment to your local machine
#
# files.download('example.txt')

# %%
from google.colab import files
raw= files.upload()
# Out:
#      <input type="file" id="files-dd8731b6-bec8-49ec-9e85-86a0a124ead6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd8731b6-bec8-49ec-9e85-86a0a124ead6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# REVIEWING THE DATASET

# %%
rdata=pd.read_csv('healthcare-dataset-stroke-data.csv')

# %% [markdown]
# SHALLOW COPYING

# %%
df=rdata.copy()

# %%
ndata=rdata.copy()

# %% [markdown]
# #EXPLORATORY DATA ANALYSIS

# %%
df.shape   #an attribute of a DataFrame that returns a tuple representing the dimensions of the DataFrame.
# Out:
# (5110, 12)

# %%
df.head() #show first few rows to learn the structure of the data
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail()#show last few rows to learn the structure of the data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.columns
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
df.info() # Display concise summary of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
# Display summary for numerical data
df.describe().T
# Out:
#                     count          mean           std    min        25%  \
# id                 5110.0  36517.829354  21161.721625  67.00  17741.250
# age                5110.0     43.226614     22.612647   0.08     25.000
# hypertension       5110.0      0.097456      0.296607   0.00      0.000
# heart_disease      5110.0      0.054012      0.226063   0.00      0.000
# avg_glucose_level  5110.0    106.147677     45.283560  55.12     77.245
# bmi                4909.0     28.893237      7.854067  10.30     23.500
# stroke             5110.0      0.048728      0.215320   0.00      0.000
#
#                          50%       75%       max
# id                 36932.000  54682.00  72940.00
# age                   45.000     61.00     82.00
# hypertension           0.000      0.00      1.00
# heart_disease          0.000      0.00      1.00
# avg_glucose_level     91.885    114.09    271.74
# bmi                   28.100     33.10     97.60
# ...

# %%
rdata.iloc[105:110,:]
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 105   2346    Male  58.0             0              0          Yes
# 106  42072  Female  50.0             1              0          Yes
# 107  12062  Female  54.0             0              0          Yes
# 108  30456  Female  79.0             0              0          Yes
# 109  59125  Female  53.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 105        Private          Urban              82.30   NaN           smokes
# 106        Private          Rural              73.18  30.3  formerly smoked
# 107  Self-employed          Rural             191.82  40.4           smokes
# 108        Private          Rural              93.05  24.2     never smoked
# 109       Govt_job          Urban              64.17  41.5     never smoked
#
#      stroke
# 105       1
# 106       1
# 107       1
# 108       1
# 109       1

# %%
for n in df.columns:
    print("the values of ",n," are")
    print(pd.unique(df[n]))
# Out:
# the values of  id  are
# [ 9046 51676 31112 ... 19723 37544 44679]
# the values of  gender  are
# ['Male' 'Female' 'Other']
# the values of  age  are
# [6.70e+01 6.10e+01 8.00e+01 4.90e+01 7.90e+01 8.10e+01 7.40e+01 6.90e+01
#  5.90e+01 7.80e+01 5.40e+01 5.00e+01 6.40e+01 7.50e+01 6.00e+01 5.70e+01
#  7.10e+01 5.20e+01 8.20e+01 6.50e+01 5.80e+01 4.20e+01 4.80e+01 7.20e+01
#  6.30e+01 7.60e+01 3.90e+01 7.70e+01 7.30e+01 5.60e+01 4.50e+01 7.00e+01
#  6.60e+01 5.10e+01 4.30e+01 6.80e+01 4.70e+01 5.30e+01 3.80e+01 5.50e+01
#  1.32e+00 4.60e+01 3.20e+01 1.40e+01 3.00e+00 8.00e+00 3.70e+01 4.00e+01
#  3.50e+01 2.00e+01 4.40e+01 2.50e+01 2.70e+01 2.30e+01 1.70e+01 1.30e+01
#  4.00e+00 1.60e+01 2.20e+01 3.00e+01 2.90e+01 1.10e+01 2.10e+01 1.80e+01
#  3.30e+01 2.40e+01 3.40e+01 3.60e+01 6.40e-01 4.10e+01 8.80e-01 5.00e+00
#  2.60e+01 3.10e+01 7.00e+00 1.20e+01 6.20e+01 2.00e+00 9.00e+00 1.50e+01
#  2.80e+01 1.00e+01 1.80e+00 3.20e-01 1.08e+00 1.90e+01 6.00e+00 1.16e+00
# ...

# %% [markdown]
# # ***HANDLING MISSING VALUES***

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5105    False
# 5106    False
# 5107    False
# 5108    False
# 5109    False
# Length: 5110, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# DETECTION OF MISSING VALUES

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %% [markdown]
# no missing values in the data frame verified by visualization

# %%
sb.heatmap(df.isnull(),cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
(df.isna().sum()*100/df.shape[0]).sort_values(ascending=True)
# Out:
# id                   0.000000
# gender               0.000000
# age                  0.000000
# hypertension         0.000000
# heart_disease        0.000000
# ever_married         0.000000
# work_type            0.000000
# Residence_type       0.000000
# avg_glucose_level    0.000000
# smoking_status       0.000000
# stroke               0.000000
# bmi                  3.933464
# dtype: float64

# %%
sb.set_style('whitegrid')
plt.figure(figsize=(12,8))
miss_values=df.isna().sum()*100/df.shape[0]
miss_values=miss_values.sort_values(ascending=False)[0:10]
ax=miss_values.plot(kind='bar')
ax.set_title('Measuring rows with most missing data')
ax.set_ylabel('Proportion')
ax.set_xlabel('Features')
ax.tick_params(axis='x',rotation=90)

# %% [markdown]
# HANDLING MISSING VALUES
#
# General Recommendations:
#
#
# Always understand the nature of missing values before deciding on a strategy.
#
#
# Consider the impact of missing data on your analysis and results.
#
#
# Document any imputation or handling strategy for transparency.

# %%
df["bmi"]=df["bmi"].fillna(df["bmi"].mean())

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# #UNIVARIATE ANALYSIS

# %% [markdown]
# FOR CATEGORICAL FEATURES

# %%
for column in df.select_dtypes(include='object').columns:
    # Bar chart
    plt.figure(figsize=(2,1))
    sb.countplot(x=df[column])
    plt.title(f'Bar Chart of {column}')
    plt.xticks(rotation=45,ha='right') #ha='right' means horizontal alignment of text in right side
    plt.show()

# %% [markdown]
# NUMERICAL FEATURES

# %% [markdown]
# HISTOGRAM

# %%
for column in df.select_dtypes(include='number').columns:
  if column== 'id':
    continue
# Histogram
  plt.figure(figsize=(2,1))
  sb.histplot(np.log(df[column]), kde=True, color='skyblue')#kde=True adds kernel density estimate plot
  plt.title(f'Histogram of {column}')
  plt.xlabel(column)
  plt.ylabel('Frequency')
  plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# BOX PLOT

# %%
#for column in df.select_dtypes(include='number').columns:
# Box plot --- summarizing distribution of numerical variable
 # plt.figure(figsize=(2,1))
  #sb.boxplot(x=df[column], color='lightcoral')
  #plt.title(f'Box Plot of {column}')
  #plt.xlabel(column)
  #plt.xticks(rotation=45)
  #plt.show()

# %% [markdown]
# BAR CHART FOR DESCRIPTIVE STATISTICS

# %%
for column in df.select_dtypes(include='number').columns:
  if column== 'id':
    continue
# Bar chart for descriptive statistics
  summary_stats = df[column].describe()
  plt.figure(figsize=(2,1))
  sb.barplot(x=summary_stats.index, y=summary_stats.values, palette='viridis')
  plt.title(f'Descriptive Statistics of {column}')
  plt.ylabel('Value')
  plt.xticks(rotation=45,ha='right')
  plt.show()

# %% [markdown]
# KERNEL DENSITY PLOT

# %%
for column in df.select_dtypes(include='number').columns:
# Kernel Density Plot-- smooth estimate of the distribution
  plt.figure(figsize=(2,1))
  sb.kdeplot(df[column], fill=True, color='orange')
  plt.title(f'Kernel Density Plot of {column}')
  plt.xlabel(column)
  plt.xticks(rotation=45)
  plt.show()

# %% [markdown]
# # ***BIVARIATE ANALYSIS***

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
# Analyze the target variable
df.groupby('stroke').mean()
df.groupby('stroke').count()
# Out:
# <ipython-input-30-e4f35d25b5fc>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('stroke').mean()
#           id  gender   age  hypertension  heart_disease  ever_married  \
# stroke
# 0       4861    4861  4861          4861           4861          4861
# 1        249     249   249           249            249           249
#
#         work_type  Residence_type  avg_glucose_level   bmi  smoking_status
# stroke
# 0            4861            4861               4861  4861            4861
# 1             249             249                249   249             249

# %%
# Numeric variables of interest
numeric_column1 = 'age'
numeric_column2 = 'bmi'

#Scatter Plot
plt.figure(figsize=(8, 6))
sb.scatterplot(x=df[numeric_column1], y=df[numeric_column2], color='skyblue')
plt.title(f'Scatter Plot between {numeric_column1} and {numeric_column2}')
plt.xlabel(numeric_column1)
plt.ylabel(numeric_column2)
plt.show()

# Box Plot
#plt.figure(figsize=(8, 6))
#sb.boxplot(x=df[numeric_column1], y=df[numeric_column2], color='lightcoral')
#plt.title(f'Box Plot between {numeric_column1} and {numeric_column2}')
#plt.xlabel(numeric_column1)
#plt.ylabel(numeric_column2)
#plt.xticks(rotation=90)
#plt.show()

# Correlation Heatmap
#correlation_matrix = df[[numeric_column1, numeric_column2]].corr()
#plt.figure(figsize=(2, 1))
#sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
#plt.title('Correlation Heatmap')
#plt.show()

# Pair Plot
sb.pairplot(df[[numeric_column1, numeric_column2]])
plt.suptitle(f'Pair Plot of {numeric_column1} and {numeric_column2}', y=1.02)
plt.show()

# %%
#find values with top 10 occurrences in 'CarName'
plt.figure(figsize=(5,3))
top_10 = (df['work_type'].value_counts()).iloc[:20]

#create bar chart to visualize top 10 values
top_10.plot(kind='pie')
# Out:
# <Axes: ylabel='work_type'>

# %%
#find values with top 10 occurrences in 'CarName'
plt.figure(figsize=(5,3))
top_10 = (df['smoking_status'].value_counts()).iloc[:20]

#create bar chart to visualize top 10 values
top_10.plot(kind='pie')
# Out:
# <Axes: ylabel='smoking_status'>

# %% [markdown]
# Use seaborn's barplot to plot the mean 'Attrition' for each category in the selected numeric column

# %%
df.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
columns_to_skip = ['id','stroke','age','avg_glucose_level','bmi']

for column in df.select_dtypes(include='number').columns:
    # Skip plotting specific columns
    if column in columns_to_skip:
        continue


    # Create a bar plot for the binary attrition
    plt.figure(figsize=(8, 5))
    plt.xticks(rotation=0)

    # Use seaborn's countplot to plot the count of 'stroke' for each category in the selected numeric column
    sb.countplot(data=df, x=column, hue='stroke', palette='Set2')

    plt.title(f'{column} vs stroke (Yes/No)')
    plt.xlabel(column)
    plt.ylabel('Count')
    plt.legend(title='stroke', labels=['No', 'Yes'])
    plt.xticks(fontsize=5)
    plt.show()

# %% [markdown]
# Use seaborn's barplot to plot the mean 'price' for each category in the selected numeric column

# %%
# Categorical variables of interest
cat_column1 = 'smoking_status'
cat_column2 = 'stroke'
# Stacked Bar Plot
cross_tab = pd.crosstab(df[cat_column1], df[cat_column2])
cross_tab.plot(kind='bar', stacked=True, colormap='viridis', figsize=(5,3))
plt.title(f'Stacked Bar Plot of {cat_column1} by {cat_column2}')
plt.xlabel(cat_column1)
plt.ylabel('Count')
plt.show()

# %%
# Categorical variables of interest
cat_column1 = 'age'
cat_column2 = 'smoking_status'
# Grouped Bar Plot
cross_tab = pd.crosstab(df[cat_column1], df[cat_column2])
cross_tab.plot(kind='bar', figsize=(15,6))
plt.title(f'Grouped Bar Plot of {cat_column1} by {cat_column2}')
plt.xlabel(cat_column1)
plt.xticks(fontsize=7)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #STATISTICAL SUMMARY
#
# Use describe for an overview of summary statistics
# summary_stats = df.describe()
#
#  Calculate individual summary statistics
#
# mean_values = df.mean()
# median_values = df.median()
# mode_values = df.mode().iloc[0]  # Mode can return multiple values, take the first one
# variance_values = df.var()
# std_dev_values = df.std()
#
#  Display the results
#
# print("Summary Statistics:")
# summary_stats
#
# print("\nIndividual Summary Statistics:")
# print("Mean:")
# print(mean_values)
#
# print("\nMedian:")
# print(median_values)
#
# print("\nMode:")
# print(mode_values)
#
# print("\nVariance:")
# print(variance_values)
#
# print("\nStandard Deviation:")
# print(std_dev_values)

# %%
df.describe().T
# Out:
#                     count          mean           std    min        25%  \
# id                 5110.0  36517.829354  21161.721625  67.00  17741.250
# age                5110.0     43.226614     22.612647   0.08     25.000
# hypertension       5110.0      0.097456      0.296607   0.00      0.000
# heart_disease      5110.0      0.054012      0.226063   0.00      0.000
# avg_glucose_level  5110.0    106.147677     45.283560  55.12     77.245
# bmi                5110.0     28.893237      7.698018  10.30     23.800
# stroke             5110.0      0.048728      0.215320   0.00      0.000
#
#                          50%       75%       max
# id                 36932.000  54682.00  72940.00
# age                   45.000     61.00     82.00
# hypertension           0.000      0.00      1.00
# heart_disease          0.000      0.00      1.00
# avg_glucose_level     91.885    114.09    271.74
# bmi                   28.400     32.80     97.60
# ...

# %%
 # Calculate correlations between all variables
num_list2 = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = num_list2.corr()
# Use heatmap for visualization
plt.figure(figsize=(20, 8))
mask = np.triu(np.ones_like(corr_matrix))
sb.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5,mask=mask )
plt.xticks(rotation=45,fontsize=10)
plt.yticks(rotation=20,fontsize=7,ha='right')
plt.title("Correlation Matrix Between All Variables")
plt.show()

# %% [markdown]
# # OUTLIERS DETECTION AND REMOVAL

# %% [markdown]
#  DETECTION

# %%
# Select numerical columns for outlier detection
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

# Create box plots for numerical columns
plt.figure(figsize=(5,3))
sb.boxplot(data=df[numerical_columns])
plt.title('Box Plots for Outlier Detection')
plt.xticks(rotation=45,ha='right',fontsize=7)
plt.show()

# Create scatter plots for pairs of numerical columns
#plt.figure(figsize=(12, 8))
#sb.pairplot(df[numerical_columns])
#plt.suptitle('Pair Plots for Outlier Detection', y=1.02)
#plt.show()
